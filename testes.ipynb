# %%
import pandas as pd

# %%
pd.DataFrame()

# %%
pd.Series([{'a' : [1,2]}, {'a' : [1,2]}], index=['2023 Compras', '2024 Compras'], name='Softwares')
# Out:
# 2023 Compras    {'a': [1, 2]}
# 2024 Compras    {'a': [1, 2]}
# Name: Softwares, dtype: object

# %%
d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d, index=['x', 'y', 'z'], copy=False)
ser.iloc[0] = 999
ser
# Out:
# x    999.0
# y      NaN
# z      NaN
# dtype: float64
